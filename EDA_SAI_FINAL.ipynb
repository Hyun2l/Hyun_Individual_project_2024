# %%
import glob
import pandas as pd
import seaborn as sns
import numpy as np

path = 'BAR_SAI'
csv_files = glob.glob(path + "/*.csv") # ALL csv in the folder

# List 
dfs = []

# Iterate through the list of files
for filename in csv_files:
    df = pd.read_csv(filename)
    dfs.append(df)

# Concatenate all the dataframes in the list into a single dataframe
combined_df = pd.concat(dfs, ignore_index=True)


print(combined_df.shape)
# Out:
# (166, 42)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                166 non-null    object
#  1   Driver              166 non-null    object
#  2   DriverNumber        166 non-null    int64
#  3   LapTime             162 non-null    object
#  4   LapNumber           166 non-null    float64
#  5   Stint               165 non-null    float64
#  6   PitOutTime          8 non-null      object
#  7   PitInTime           9 non-null      object
#  8   Sector1Time         161 non-null    object
#  9   Sector2Time         165 non-null    object
#  10  Sector3Time         165 non-null    object
#  11  Sector1SessionTime  161 non-null    object
#  12  Sector2SessionTime  165 non-null    object
#  13  Sector3SessionTime  165 non-null    object
#  14  SpeedI1             130 non-null    float64
# ...

# %%
#Encoding bool to int
combined_df['Rainfall'] = combined_df['Rainfall'].astype(int)

combined_df['Rainfall'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Rainfall, dtype: int64

# %%
""" print(combined_df['LapTime'][100])
print(combined_df['LapTime'][100].split()) # divide string based on the empty spaces
print(combined_df['LapTime'][100].split()[0]) # n
print(combined_df['LapTime'][100].split()[1]) # days 
print(combined_df['LapTime'][100].split()[2]) # Time

print(combined_df['LapTime'][100].split()[2])

print(combined_df['LapTime'][100].split()[2].split(':')[0]) # Hour
print(combined_df['LapTime'][100].split()[2].split(':')[1]) # Minute
print(combined_df['LapTime'][100].split()[2].split(':')[2]) # SS.mmmm
"""
# Out:
# " print(combined_df['LapTime'][100])\nprint(combined_df['LapTime'][100].split()) # divide string based on the empty spaces\nprint(combined_df['LapTime'][100].split()[0]) # n\nprint(combined_df['LapTime'][100].split()[1]) # days \nprint(combined_df['LapTime'][100].split()[2]) # Time\n\nprint(combined_df['LapTime'][100].split()[2])\n\nprint(combined_df['LapTime'][100].split()[2].split(':')[0]) # Hour\nprint(combined_df['LapTime'][100].split()[2].split(':')[1]) # Minute\nprint(combined_df['LapTime'][100].split()[2].split(':')[2]) # SS.mmmm\n"

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the size of the figure
plt.figure(figsize=(20, 20))

# Now create the barplot
sns.barplot(x='TrackTemp', y='LapTime', data=combined_df)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt



plt.rc('font', size = 11)
fig, axes = plt.subplots(nrows = 3)
plt.tight_layout()
fig.set_size_inches(10,50)

sns.pointplot(x='TrackTemp', y='LapTime', data=combined_df,hue = 'Encoded_Rainfall', ax=axes[0])
# Out:
# <Axes: xlabel='TrackTemp', ylabel='LapTime'>
