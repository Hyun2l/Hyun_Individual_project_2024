# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import glob

path = '2019/Austraian_2019' 
csv_files = glob.glob(path + "/*.csv")

# List 
dfs = []

# Iterate through the list of files
for filename in csv_files:
    df = pd.read_csv(filename)
    dfs.append(df)

# Concatenate all the dataframes in the list into a single dataframe
combined_df = pd.concat(dfs, ignore_index=True)

print(combined_df.shape)
# Out:
# (1401, 38)

# %%
df.head()
# Out:
#                      Time Driver  DriverNumber                 LapTime  \
# 0  0 days 00:33:11.269000    BOT            77  0 days 00:01:12.813000
# 1  0 days 00:34:11.282000    BOT            77  0 days 00:01:09.891000
# 2  0 days 00:36:11.323000    BOT            77  0 days 00:01:09.733000
# 3  0 days 00:37:11.321000    BOT            77  0 days 00:01:09.492000
# 4  0 days 00:38:11.334000    BOT            77  0 days 00:01:09.411000
#
#    LapNumber  Stint PitOutTime PitInTime             Sector1Time  \
# 0        1.0    1.0        NaN       NaN                     NaN
# 1        2.0    1.0        NaN       NaN  0 days 00:00:17.497000
# 2        3.0    1.0        NaN       NaN  0 days 00:00:17.466000
# 3        4.0    1.0        NaN       NaN  0 days 00:00:17.430000
# 4        5.0    1.0        NaN       NaN  0 days 00:00:17.430000
#
#               Sector2Time  ... DeletedReason FastF1Generated IsAccurate  \
# 0  0 days 00:00:30.967000  ...           NaN           False      False
# 1  0 days 00:00:31.128000  ...           NaN           False       True
# 2  0 days 00:00:31.007000  ...           NaN           False       True
# 3  0 days 00:00:30.930000  ...           NaN           False       True
# 4  0 days 00:00:30.885000  ...           NaN           False       True
#
#   AirTemp  Humidity  Pressure  Rainfall  TrackTemp  WindDirection WindSpeed
# 0    33.9      19.8     941.0     False       51.2            260       1.2
# 1    33.8      19.1     941.0     False       51.4            239       1.8
# 2    33.9      19.4     941.0     False       51.3             14       0.8
# 3    34.1      18.9     941.0     False       51.3            129       0.7
# 4    34.2      19.0     940.9     False       51.2             19       1.2
#
# [5 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 38 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                71 non-null     object
#  1   Driver              71 non-null     object
#  2   DriverNumber        71 non-null     int64
#  3   LapTime             71 non-null     object
#  4   LapNumber           71 non-null     float64
#  5   Stint               71 non-null     float64
#  6   PitOutTime          1 non-null      object
#  7   PitInTime           1 non-null      object
#  8   Sector1Time         70 non-null     object
#  9   Sector2Time         71 non-null     object
#  10  Sector3Time         71 non-null     object
#  11  Sector1SessionTime  69 non-null     object
#  12  Sector2SessionTime  71 non-null     object
#  13  Sector3SessionTime  71 non-null     object
#  14  SpeedI1             63 non-null     float64
#  15  SpeedI2             71 non-null     float64
#  16  SpeedFL             70 non-null     float64
#  17  SpeedST             71 non-null     float64
#  18  IsPersonalBest      71 non-null     bool
#  19  Compound            71 non-null     object
#  20  TyreLife            71 non-null     float64
#  21  FreshTyre           71 non-null     bool
#  22  Team                71 non-null     object
#  23  LapStartTime        71 non-null     object
#  24  LapStartDate        71 non-null     object
#  25  TrackStatus         71 non-null     int64
#  26  Position            71 non-null     float64
#  27  Deleted             71 non-null     bool
#  28  DeletedReason       0 non-null      float64
#  29  FastF1Generated     71 non-null     bool
#  30  IsAccurate          71 non-null     bool
#  31  AirTemp             71 non-null     float64
#  32  Humidity            71 non-null     float64
#  33  Pressure            71 non-null     float64
#  34  Rainfall            71 non-null     bool
#  35  TrackTemp           71 non-null     float64
#  36  WindDirection       71 non-null     int64
#  37  WindSpeed           71 non-null     float64
# dtypes: bool(6), float64(14), int64(3), object(15)
# memory usage: 18.3+ KB

# %%
df_null = df.isnull()
df_null.head()
# Out:
#     Time  Driver  DriverNumber  LapTime  LapNumber  Stint  PitOutTime  \
# 0  False   False         False    False      False  False        True
# 1  False   False         False    False      False  False        True
# 2  False   False         False    False      False  False        True
# 3  False   False         False    False      False  False        True
# 4  False   False         False    False      False  False        True
#
#    PitInTime  Sector1Time  Sector2Time  ...  DeletedReason  FastF1Generated  \
# 0       True         True        False  ...           True            False
# 1       True        False        False  ...           True            False
# 2       True        False        False  ...           True            False
# 3       True        False        False  ...           True            False
# 4       True        False        False  ...           True            False
#
#    IsAccurate  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0       False    False     False     False     False      False
# 1       False    False     False     False     False      False
# 2       False    False     False     False     False      False
# 3       False    False     False     False     False      False
# 4       False    False     False     False     False      False
#
#    WindDirection  WindSpeed
# 0          False      False
# 1          False      False
# 2          False      False
# 3          False      False
# 4          False      False
#
# [5 rows x 38 columns]

# %%
df_null.sum()
# Out:
# Time                   0
# Driver                 0
# DriverNumber           0
# LapTime                0
# LapNumber              0
# Stint                  0
# PitOutTime            70
# PitInTime             70
# Sector1Time            1
# Sector2Time            0
# Sector3Time            0
# Sector1SessionTime     2
# Sector2SessionTime     0
# Sector3SessionTime     0
# SpeedI1                8
# SpeedI2                0
# SpeedFL                1
# SpeedST                0
# IsPersonalBest         0
# Compound               0
# TyreLife               0
# FreshTyre              0
# Team                   0
# LapStartTime           0
# LapStartDate           0
# TrackStatus            0
# Position               0
# Deleted                0
# DeletedReason         71
# FastF1Generated        0
# IsAccurate             0
# AirTemp                0
# Humidity               0
# Pressure               0
# Rainfall               0
# TrackTemp              0
# WindDirection          0
# WindSpeed              0
# dtype: int64

# %%
df_null.sum().plot.barh()
# Out:
# <Axes: >

# %%
try:
    df = df.drop(columns=['DeletedReason', 'PitInTime', 'PitOutTime'])
except KeyError as e:
    print(f"One or more columns not found in the DataFrame: {e}")


print(df.columns)

# If the columns are correctly dropped, you can proceed with the visualization
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 4))
sns.heatmap(df.isnull(), cmap="Greys_r")
plt.show()
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'Sector1Time', 'Sector2Time', 'Sector3Time', 'Sector1SessionTime',
#        'Sector2SessionTime', 'Sector3SessionTime', 'SpeedI1', 'SpeedI2',
#        'SpeedFL', 'SpeedST', 'IsPersonalBest', 'Compound', 'TyreLife',
#        'FreshTyre', 'Team', 'LapStartTime', 'LapStartDate', 'TrackStatus',
#        'Position', 'Deleted', 'FastF1Generated', 'IsAccurate', 'AirTemp',
#        'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection',
#        'WindSpeed'],
#       dtype='object')

# %%
df["LapTime"]
# Out:
# 0     0 days 00:01:12.813000
# 1     0 days 00:01:09.891000
# 2     0 days 00:01:09.733000
# 3     0 days 00:01:09.492000
# 4     0 days 00:01:09.411000
#                ...
# 66    0 days 00:01:09.013000
# 67    0 days 00:01:08.905000
# 68    0 days 00:01:09.554000
# 69    0 days 00:01:09.556000
# 70    0 days 00:01:09.699000
# Name: LapTime, Length: 71, dtype: object

# %%
df["LapTime"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 71 entries, 0 to 70
# Series name: LapTime
# Non-Null Count  Dtype
# --------------  -----
# 71 non-null     object
# dtypes: object(1)
# memory usage: 700.0+ bytes

# %%
df['LapTime'] = pd.to_timedelta(df['LapTime'])

df['LapTime'].info()

"""# Ensure that LapTime is in timedelta format
df['LapTime'] = pd.to_timedelta(df['LapTime'])

# Convert the LapTime to total seconds
df['LapTimeSeconds'] = df['LapTime'].dt.total_seconds()

# Convert the LapTime to total milliseconds
df['LapTimeMilliseconds'] = df['LapTime'].dt.total_seconds() * 1000

"""
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 71 entries, 0 to 70
# Series name: LapTime
# Non-Null Count  Dtype
# --------------  -----
# 71 non-null     timedelta64[ns]
# dtypes: timedelta64[ns](1)
# memory usage: 700.0 bytes
# "# Ensure that LapTime is in timedelta format\ndf['LapTime'] = pd.to_timedelta(df['LapTime'])\n\n# Convert the LapTime to total seconds\ndf['LapTimeSeconds'] = df['LapTime'].dt.total_seconds()\n\n# Convert the LapTime to total milliseconds\ndf['LapTimeMilliseconds'] = df['LapTime'].dt.total_seconds() * 1000\n\n"

# %%
numeric_columns = df.select_dtypes(include=[np.number])
medians = numeric_columns.median(numeric_only=True)
df = df.fillna(medians)


df = df.dropna()



mean = df[numeric_columns.columns].mean()
std = df[numeric_columns.columns].std()
z_scores = (df[numeric_columns.columns] - mean) / std


df_filtered = df[(z_scores < 3).all(axis=1)]

nan_columns = df.isna().all(axis=0)
print("Columns with all NaN values:", nan_columns[nan_columns].index.tolist())

# Check for any entirely NaN rows
nan_rows = df.isna().all(axis=1)
print("Number of rows with all NaN values:", nan_rows.sum())
# Out:
# Columns with all NaN values: []
# Number of rows with all NaN values: 0

# %%
# Histograms for numerical data
df.hist(bins=15, figsize=(15, 10), layout=(5, 4))
plt.show()

# %%
# Boxplots for weather conditions to identify outliers
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[['AirTemp', 'Humidity', 'Pressure', 'TrackTemp']])
plt.show()

# %%
# Compute correlation matrix
corr_matrix = df.corr(numeric_only=True)

# Heatmap to visualize correlations
plt.figure(figsize=(20, 12))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# Scatter plots for specific weather conditions vs. lap time
plt.figure(figsize=(12, 6))
sns.scatterplot(x='TrackTemp', y='LapTime', data=df)
plt.title('Track Temperature vs. Lap Time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 11
#       9 # Scatter plots for specific weather conditions vs. lap time
#      10 plt.figure(figsize=(12, 6))
# ---> 11 sns.scatterplot(x='TrackTemp', y='LapTime', data=df)
#      12 plt.title('Track Temperature vs. Lap Time')
#      13 plt.show()
#
# File /opt/anaconda3/envs/COMS30035_labs/lib/python3.11/site-packages/seaborn/relational.py:761, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     758 color = kwargs.pop("color", None)
#     759 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 761 p.plot(ax, kwargs)
#     763 return ax
#
# File /opt/anaconda3/envs/COMS30035_labs/lib/python3.11/site-packages/seaborn/relational.py:573, in _ScatterPlotter.plot(self, ax, kws)
#     570     kws.setdefault("edgecolor", "w")
#     572 # Draw the scatter plot
# --> 573 points = ax.scatter(x=x, y=y, **kws)
#     575 # Apply the mapping from semantic variables to artist attributes
#     577 if "hue" in self.variables:
#
# File /opt/anaconda3/envs/COMS30035_labs/lib/python3.11/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/envs/COMS30035_labs/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4671, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4666     elif np.iterable(linewidths):
#    4667         linewidths = [
#    4668             lw if lw is not None else mpl.rcParams['lines.linewidth']
#    4669             for lw in linewidths]
# -> 4671 offsets = np.ma.column_stack([x, y])
#    4673 collection = mcoll.PathCollection(
#    4674     (path,), scales,
#    4675     facecolors=colors,
#    (...)
#    4680     alpha=alpha,
#    4681 )
#    4682 collection.set_transform(mtransforms.IdentityTransform())
#
# File /opt/anaconda3/envs/COMS30035_labs/lib/python3.11/site-packages/numpy/ma/extras.py:290, in _fromnxfunction_seq.__call__(self, x, *args, **params)
#     288 def __call__(self, x, *args, **params):
#     289     func = getattr(np, self.__name__)
# --> 290     _d = func(tuple([np.asarray(a) for a in x]), *args, **params)
#     291     _m = func(tuple([getmaskarray(a) for a in x]), *args, **params)
#     292     return masked_array(_d, mask=_m)
#
# File <__array_function__ internals>:200, in column_stack(*args, **kwargs)
#
# File /opt/anaconda3/envs/COMS30035_labs/lib/python3.11/site-packages/numpy/lib/shape_base.py:656, in column_stack(tup)
#     654         arr = array(arr, copy=False, subok=True, ndmin=2).T
#     655     arrays.append(arr)
# --> 656 return _nx.concatenate(arrays, 1)
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# TypeError: The DType <class 'numpy.dtype[float64]'> could not be promoted by <class 'numpy.dtype[timedelta64]'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtype[float64]'>, <class 'numpy.dtype[timedelta64]'>)
